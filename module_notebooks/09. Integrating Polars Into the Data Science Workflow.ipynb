# %% [markdown]
# # 09. Integrating Polars Into the Data Science Workflow

# %% [markdown]
# By this point in this course, we've gained a lot of dexterity with `polars`; now, it's time to use it in a real data science problem!
#
# The problem we will be trying to solve is **tip amount prediction**, using the NYC taxi rides data that we've been using throughout this course. The goal here is to provide a service to taxi drivers which, before starting a taxi ride, they can plug the details of their ride into, and receive a prediction for what tip amount that customer can be expected to pay. They could then use this information to inform themselves on how to best interact with their passengers to increase their tip; furthermore, feature importance insights from such a model could help a taxi driver decide the best places in the city to work, or the best times in the week, etc.
#
# We'll go through the entire data science process:
# 1. Setting Up the Environment
# 2. Loading Data
# 4. Brief Data Exploration
# 3. Cleaning and Preparing the Data
# 4. Feature Engineering and Selection
# 5. Model Building
# 6. Model Evaluation
# 7. Discussion
#
# And we'll also check out a few new data science tools in the `polars` library along the way.
#
# Let's get into it!

# %% [markdown]
# ## 9.1. Setting up the Environment

# %%
# %pip install -U polars scikit-learn matplotlib lightgbm xgboost hvplot
# Out:
# Requirement already satisfied: polars in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (1.19.0)
# Requirement already satisfied: scikit-learn in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: matplotlib in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: lightgbm in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (4.5.0)
# Requirement already satisfied: xgboost in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (2.1.3)
# Requirement already satisfied: hvplot in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.19.5 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from scikit-learn) (1.26.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from matplotlib) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: bokeh>=3.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from hvplot) (3.6.2)
# Requirement already satisfied: colorcet>=2 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from hvplot) (3.1.0)
# Requirement already satisfied: holoviews>=1.19.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from hvplot) (1.20.0)
# Requirement already satisfied: pandas>=1.3 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from hvplot) (2.2.2)
# Requirement already satisfied: panel>=1.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from hvplot) (1.5.5)
# Requirement already satisfied: param<3.0,>=1.12.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from hvplot) (2.2.0)
# Requirement already satisfied: Jinja2>=2.9 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from bokeh>=3.1->hvplot) (3.1.5)
# Requirement already satisfied: PyYAML>=3.10 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from bokeh>=3.1->hvplot) (6.0.2)
# Requirement already satisfied: tornado>=6.2 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from bokeh>=3.1->hvplot) (6.4.2)
# Requirement already satisfied: xyzservices>=2021.09.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from bokeh>=3.1->hvplot) (2024.9.0)
# Requirement already satisfied: pyviz-comms>=2.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from holoviews>=1.19.0->hvplot) (3.0.3)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from pandas>=1.3->hvplot) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from pandas>=1.3->hvplot) (2023.3)
# Requirement already satisfied: bleach in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from panel>=1.0->hvplot) (6.2.0)
# Requirement already satisfied: linkify-it-py in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from panel>=1.0->hvplot) (2.0.3)
# Requirement already satisfied: markdown in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from panel>=1.0->hvplot) (3.7)
# Requirement already satisfied: markdown-it-py in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from panel>=1.0->hvplot) (3.0.0)
# Requirement already satisfied: mdit-py-plugins in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from panel>=1.0->hvplot) (0.4.2)
# Requirement already satisfied: requests in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from panel>=1.0->hvplot) (2.31.0)
# Requirement already satisfied: tqdm in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from panel>=1.0->hvplot) (4.67.1)
# Requirement already satisfied: typing-extensions in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from panel>=1.0->hvplot) (4.12.2)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from Jinja2>=2.9->bokeh>=3.1->hvplot) (3.0.2)
# Requirement already satisfied: webencodings in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from bleach->panel>=1.0->hvplot) (0.5.1)
# Requirement already satisfied: uc-micro-py in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from linkify-it-py->panel>=1.0->hvplot) (1.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from markdown-it-py->panel>=1.0->hvplot) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from requests->panel>=1.0->hvplot) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from requests->panel>=1.0->hvplot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from requests->panel>=1.0->hvplot) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages (from requests->panel>=1.0->hvplot) (2023.7.22)
# WARNING: Error parsing dependencies of ipykernel: [Errno 2] No such file or directory: '/home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages/ipykernel-6.29.0.dist-info/METADATA'
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import `polars` as usual...

# %%
import polars as pl

# %run setup.py
# Out:
# /data/datasets/data/yellow_tripdata_2024-03.parquet already exists
# /data/datasets/data/taxi_zone_lookup.csv already exists
#
# local_parquet = /data/datasets/data/yellow_tripdata_2024-03.parquet
# local_csv = /data/datasets/data/yellow_tripdata_2024-03.csv
# taxi_zone_lookup_local = /data/datasets/data/taxi_zone_lookup.csv
# taxi_zone_lookup_parquet = /data/datasets/data/taxi_zone_lookup.parquet

# %% [markdown]
# But also import some other tools from the data science suite that we'll need throughout this notebook.

# %%
import matplotlib.pyplot as plt
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## 9.2. Loading Data

# %% [markdown]
# First, we load the data about zones:

# %%
zone_column_rename_mapping = {
    "LocationID": "location_id",
    "Borough": "borough",
    "Zone": "zone",
}
zones_df = pl.read_parquet(taxi_zone_lookup_parquet).rename(
    zone_column_rename_mapping
)
zones_df.head()
# Out:
# shape: (5, 4)
# ┌─────────────┬───────────────┬─────────────────────────┬──────────────┐
# │ location_id ┆ borough       ┆ zone                    ┆ service_zone │
# │ ---         ┆ ---           ┆ ---                     ┆ ---          │
# │ i64         ┆ str           ┆ str                     ┆ str          │
# ╞═════════════╪═══════════════╪═════════════════════════╪══════════════╡
# │ 1           ┆ EWR           ┆ Newark Airport          ┆ EWR          │
# │ 2           ┆ Queens        ┆ Jamaica Bay             ┆ Boro Zone    │
# │ 3           ┆ Bronx         ┆ Allerton/Pelham Gardens ┆ Boro Zone    │
# │ 4           ┆ Manhattan     ┆ Alphabet City           ┆ Yellow Zone  │
# │ 5           ┆ Staten Island ┆ Arden Heights           ┆ Boro Zone    │
# └─────────────┴───────────────┴─────────────────────────┴──────────────┘

# %% [markdown]
# Then, we load in the yellow trips taxi data, for both february and march (using `*` file pattern notation), joining in the zone information as before:

# %%
yellow_rides_column_rename_mapping = {
    "VendorID": "vendor_id",
    "RatecodeID": "ratecode_id",
    "PULocationID": "pu_location_id",
    "DOLocationID": "do_location_id",
    "Airport_fee": "airport_fee",
}

zone_df_columns = [
    "borough",
    "zone",
    "service_zone",
]

rides_df_raw = (
    pl.read_parquet("/data/datasets/data/yellow_tripdata_2024-*.parquet")
    .rename(yellow_rides_column_rename_mapping)
    .join(zones_df, left_on="pu_location_id", right_on="location_id")
    .rename(
        {
            zone_df_column: f"pu_{zone_df_column}"
            for zone_df_column in zone_df_columns
        }
    )
    .join(zones_df, left_on="do_location_id", right_on="location_id")
    .rename(
        {
            zone_df_column: f"do_{zone_df_column}"
            for zone_df_column in zone_df_columns
        }
    )
)

# %%
display(rides_df_raw.shape)
display(rides_df_raw.head())
# Out:
# (6590154, 25)
# shape: (5, 25)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ vendor_id ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ pu_servic ┆ do_boroug ┆ do_zone   ┆ do_servi │
# │ ---       ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ e_zone    ┆ h         ┆ ---       ┆ ce_zone  │
# │ i32       ┆ me        ┆ ime       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ str       ┆ ---      │
# │           ┆ ---       ┆ ---       ┆ i64       ┆   ┆ str       ┆ str       ┆           ┆ str      │
# │           ┆ datetime[ ┆ datetime[ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Yellow    ┆ Manhattan ┆ Upper     ┆ Yellow   │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆ Zone      ┆           ┆ East Side ┆ Zone     │
# │           ┆ 00:04:45  ┆ 00:19:58  ┆           ┆   ┆           ┆           ┆ North     ┆          │
# │ 2         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Yellow    ┆ Manhattan ┆ Washingto ┆ Boro     │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆ Zone      ┆           ┆ n Heights ┆ Zone     │
# │           ┆ 00:56:31  ┆ 01:10:53  ┆           ┆   ┆           ┆           ┆ North     ┆          │
# │ 2         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 2         ┆ … ┆ Airports  ┆ Manhattan ┆ World     ┆ Yellow   │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆           ┆           ┆ Trade     ┆ Zone     │
# │           ┆ 00:07:50  ┆ 00:43:12  ┆           ┆   ┆           ┆           ┆ Center    ┆          │
# │ 1         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Yellow    ┆ Manhattan ┆ Midtown   ┆ Yellow   │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆ Zone      ┆           ┆ North     ┆ Zone     │
# │           ┆ 00:01:49  ┆ 00:10:47  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Yellow    ┆ Manhattan ┆ East      ┆ Yellow   │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆ Zone      ┆           ┆ Village   ┆ Zone     │
# │           ┆ 00:37:35  ┆ 00:51:15  ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Looks good to go!

# %% [markdown]
# ## 9.3. Brief Data Exploration

# %% [markdown]
# Before we proceed with any machine learning, let's first have a look at the data, viewed through the lens of the machine learning problem we're going to solve, keeping an eye out for anything we'll need to take care of during data cleaning and preparation:

# %%
rides_df_raw.describe()
# Out:
# shape: (9, 26)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ vendor_id ┆ tpep_pick ┆ tpep_drop ┆ … ┆ pu_servic ┆ do_boroug ┆ do_zone   ┆ do_servi │
# │ ---       ┆ ---       ┆ up_dateti ┆ off_datet ┆   ┆ e_zone    ┆ h         ┆ ---       ┆ ce_zone  │
# │ str       ┆ f64       ┆ me        ┆ ime       ┆   ┆ ---       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆ ---       ┆ ---       ┆   ┆ str       ┆ str       ┆           ┆ str      │
# │           ┆           ┆ str       ┆ str       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 6.590154e ┆ 6590154   ┆ 6590154   ┆ … ┆ 6590154   ┆ 6590154   ┆ 6590154   ┆ 6590154  │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ null_coun ┆ 0.0       ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 1.756811  ┆ 2024-03-0 ┆ 2024-03-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ 2 23:29:0 ┆ 2 23:45:2 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 8.306262  ┆ 9.766303  ┆   ┆           ┆           ┆           ┆          │
# │ std       ┆ 0.430632  ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ min       ┆ 1.0       ┆ 2002-12-3 ┆ 2002-12-3 ┆ … ┆ Airports  ┆ Bronx     ┆ Allerton/ ┆ Airports │
# │           ┆           ┆ 1         ┆ 1         ┆   ┆           ┆           ┆ Pelham    ┆          │
# │           ┆           ┆ 22:17:10  ┆ 22:42:24  ┆   ┆           ┆           ┆ Gardens   ┆          │
# │ 25%       ┆ 2.0       ┆ 2024-02-1 ┆ 2024-02-1 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ 6         ┆ 6         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 23:06:24  ┆ 23:22:02  ┆   ┆           ┆           ┆           ┆          │
# │ 50%       ┆ 2.0       ┆ 2024-03-0 ┆ 2024-03-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ 3         ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 14:05:02  ┆ 14:23:32  ┆   ┆           ┆           ┆           ┆          │
# │ 75%       ┆ 2.0       ┆ 2024-03-1 ┆ 2024-03-1 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ 7         ┆ 7         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 12:36:18  ┆ 12:54:35  ┆   ┆           ┆           ┆           ┆          │
# │ max       ┆ 6.0       ┆ 2024-04-0 ┆ 2024-04-0 ┆ … ┆ Yellow    ┆ Unknown   ┆ Yorkville ┆ Yellow   │
# │           ┆           ┆ 1         ┆ 2         ┆   ┆ Zone      ┆           ┆ West      ┆ Zone     │
# │           ┆           ┆ 00:34:55  ┆ 18:08:46  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# A few notes:
# - Some rides had pickup and dropoff times that took place outside of the data's known time range of beginning of february 2024 until the end of march 2024 (for example the minimum `"tpep_pickup_datetime"` is `"2002-12-31 22:17:10"`.
# - A few columns are missing data, all in exactly `611800` rows (about `10%` of the data): `"passenger_count"`, `"ratecode_id"`, `"store_and_fwd_flag"`, `"congestion_surcharge"`, and `"airport_fee"`.
# - As we've seen throughout the course, some fields have impossibly subzero values, namely `"trip_distance"` and some of the currency columns (e.g. the mnimum `"fare_amount"` was `-$999`).

# %% [markdown]
# To the point that a few columns are missing data, let's double check the percentage of that:

# %%
rides_df_raw.select(pl.all().null_count() / pl.len())
# Out:
# shape: (1, 25)
# ┌───────────┬────────────┬───────────┬───────────┬───┬───────────┬───────────┬─────────┬───────────┐
# │ vendor_id ┆ tpep_picku ┆ tpep_drop ┆ passenger ┆ … ┆ pu_servic ┆ do_boroug ┆ do_zone ┆ do_servic │
# │ ---       ┆ p_datetime ┆ off_datet ┆ _count    ┆   ┆ e_zone    ┆ h         ┆ ---     ┆ e_zone    │
# │ f64       ┆ ---        ┆ ime       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ f64     ┆ ---       │
# │           ┆ f64        ┆ ---       ┆ f64       ┆   ┆ f64       ┆ f64       ┆         ┆ f64       │
# │           ┆            ┆ f64       ┆           ┆   ┆           ┆           ┆         ┆           │
# ╞═══════════╪════════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═════════╪═══════════╡
# │ 0.0       ┆ 0.0        ┆ 0.0       ┆ 0.092835  ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0     ┆ 0.0       │
# └───────────┴────────────┴───────────┴───────────┴───┴───────────┴───────────┴─────────┴───────────┘

# %% [markdown]
# Since all columns with missing data seem to have the exact same number of missing rows, hopefully they are null together. Let's check:

# %%
cols_with_null = [
    "passenger_count",
    "ratecode_id",
    "store_and_fwd_flag",
    "congestion_surcharge",
    "airport_fee",
]
rides_df_raw.select(
    pl.all_horizontal(pl.col(cols_with_null).is_null()).sum() / pl.len()
)
# Out:
# shape: (1, 1)
# ┌─────────────────┐
# │ passenger_count │
# │ ---             │
# │ f64             │
# ╞═════════════════╡
# │ 0.092835        │
# └─────────────────┘

# %% [markdown]
# Indeed, they are all null together! We'll take care of this when it comes time to clean and prepare the data.

# %% [markdown]
# #### Plots of the target distribution

# %% [markdown]
# Next, let's plot a histogram of the target variable. We can do this by plotting directly in `polars`; to do this `polars` enables a few backends. Here, we will use the [`hvplot` library](https://hvplot.holoviz.org/) as backend:

# %%
import hvplot.polars
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='96b6f664-1fa0-428a-bbf0-a7938708640b'>
#   <div id="cacaa207-781b-4ff5-a2ac-c88f65428042" data-root-id="96b6f664-1fa0-428a-bbf0-a7938708640b" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1b41b820-e0c9-41f2-8387-a279b6389184":{"version":"3.6.2","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"96b6f664-1fa0-428a-bbf0-a7938708640b"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"ae0ad6e8-be47-4ff8-b776-74ede4fe4bc5","attributes":{"plot_id":"96b6f664-1fa0-428a-bbf0-a7938708640b","comm_id":"89827b1aabc745d4ad45352975958439","client_comm_id":"5fa6c91f0fd3458e9f92c2fd32828f09"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"1b41b820-e0c9-41f2-8387-a279b6389184","roots":{"96b6f664-1fa0-428a-bbf0-a7938708640b":"cacaa207-781b-4ff5-a2ac-c88f65428042"},"root_ids":["96b6f664-1fa0-428a-bbf0-a7938708640b"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
rides_df_raw.hvplot.hist("tip_amount", bins=5000, xlim=(-1, 20))
# Out:
# :Histogram   [tip_amount]   (Count)

# %% [markdown]
# It's almost as if the distribution function over `"tip_amount"` is piecewise: either the `"tip_amount"` is zero, or it's non-zero; if it's non-zero, then it follows a normal or log-normal distribution.
#
# Next, let's plot an ECDF of the target variable to more easily see the share of different values for `"tip_amount"`. Unfortunately, `hvplot` doesn't offer an ECDF, but `matplotlib` does, and it thankfully supports `polars` series as input:

# %%
plt.ecdf(rides_df_raw["tip_amount"])
plt.xlim(1, 1000)
plt.xscale("log")
plt.title("ECDF of Tip Amounts")
plt.xlabel("Tip Amount ($)")
plt.ylabel("ECDF")
plt.show()

# %% [markdown]
# We can see some curious stuff in the target variable:
# - `~35%` of rides had a `"tip_amount"` equal to zero.
# - The next `~60%` of rides had a `"tip_amount"` between `$0` and `$10`.
# - The remaining `~5%` of rides had a `"tip_amount"` of over `$10`.

# %% [markdown]
# #### Correlation

# %% [markdown]
# Like `pandas`, `polars` offers a convenient method on dataframes for checking correlation between columns (if you'd like to downsample the data for running this cell more quickly, you can uncomment the `.sample` call):

# %%
corr = (
    rides_df_raw.select(pl.col([pl.Int32, pl.Int64, pl.Float64]))
    .filter(pl.all_horizontal(pl.all().is_not_null()))
    # .sample(100000)  # Uncomment for speed.
    .corr()
)
(corr.select(pl.Series(corr.columns), pl.all()))
# Out:
# shape: (16, 17)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │           ┆ vendor_id ┆ passenger ┆ trip_dist ┆ … ┆ improveme ┆ total_amo ┆ congestio ┆ airport_ │
# │ ---       ┆ ---       ┆ _count    ┆ ance      ┆   ┆ nt_surcha ┆ unt       ┆ n_surchar ┆ fee      │
# │ str       ┆ f64       ┆ ---       ┆ ---       ┆   ┆ rge       ┆ ---       ┆ ge        ┆ ---      │
# │           ┆           ┆ f64       ┆ f64       ┆   ┆ ---       ┆ f64       ┆ ---       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆ f64       ┆           ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ vendor_id ┆ 1.0       ┆ 0.100679  ┆ -0.002526 ┆ … ┆ -0.06444  ┆ 0.018154  ┆ 0.011482  ┆ 0.038793 │
# │ passenger ┆ 0.100679  ┆ 1.0       ┆ 0.00074   ┆ … ┆ -0.001811 ┆ 0.036825  ┆ 0.011627  ┆ 0.021867 │
# │ _count    ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ trip_dist ┆ -0.002526 ┆ 0.00074   ┆ 1.0       ┆ … ┆ 0.000259  ┆ 0.037948  ┆ -0.01553  ┆ 0.027287 │
# │ ance      ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ratecode_ ┆ -0.188865 ┆ -0.040695 ┆ 0.022801  ┆ … ┆ 0.010366  ┆ 0.059747  ┆ -0.300915 ┆ -0.02116 │
# │ id        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 6        │
# │ pu_locati ┆ -0.001779 ┆ -0.009979 ┆ -0.007584 ┆ … ┆ 0.01077   ┆ -0.112485 ┆ 0.116354  ┆ -0.15017 │
# │ on_id     ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 5        │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ tolls_amo ┆ 0.01068   ┆ 0.029557  ┆ 0.031529  ┆ … ┆ 0.060333  ┆ 0.69077   ┆ -0.093243 ┆ 0.480222 │
# │ unt       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ improveme ┆ -0.06444  ┆ -0.001811 ┆ 0.000259  ┆ … ┆ 1.0       ┆ 0.266496  ┆ 0.611443  ┆ 0.093072 │
# │ nt_surcha ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ rge       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ total_amo ┆ 0.018154  ┆ 0.036825  ┆ 0.037948  ┆ … ┆ 0.266496  ┆ 1.0       ┆ -0.051653 ┆ 0.623741 │
# │ unt       ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ congestio ┆ 0.011482  ┆ 0.011627  ┆ -0.01553  ┆ … ┆ 0.611443  ┆ -0.051653 ┆ 1.0       ┆ -0.25509 │
# │ n_surchar ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ 9        │
# │ ge        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ airport_f ┆ 0.038793  ┆ 0.021867  ┆ 0.027287  ┆ … ┆ 0.093072  ┆ 0.623741  ┆ -0.255099 ┆ 1.0      │
# │ ee        ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# By default, `polars` only shows `10` rows, so we can't see the whole chart. We can change that with `polars` config:

# %%
pl.Config.set_tbl_rows(16)
# Out:
# polars.config.Config

# %% [markdown]
# Unsurprisingly, `"tip_amount"` is highly correlated with `"total_amount"`; let's have a closer look, again using the built-in `.plot` namespace:

# %%
(
    rides_df_raw.sample(10000).hvplot.scatter(  # Uncomment for speed.
        x="total_amount",
        y="tip_amount",
        xlim=(0, 200),
        ylim=(0, 40),
    )
)
# Out:
# :Scatter   [total_amount]   (tip_amount)

# %% [markdown]
# There are a few interesting things here:
# 1. There are three distinct flat lines at `$5`, `$10`, and `$15`--these are common tip amounts.
# 2. There are three distinct diagonal lines at `y = {.15, .20, and .25} * total_amount`--these are common tip percentages.
#
# `"tip_amount"` might be more predictable than we thought!

# %% [markdown]
# ## 9.4. Cleaning and Preparing the Data

# %% [markdown]
# Over the course of this course, we've compiled some filters of impossible data, such as rides without passengers, and rides that had a pickup that occurred after the dropoff, and some of the other data issues we just discovered in the prior section (such as missing values). We'd like to handle this bad data before jumping into machine learning, so first let's quantify the scope of the issue:

# %%
rides_df_raw.describe()
# Out:
# shape: (9, 26)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ vendor_id ┆ tpep_pick ┆ tpep_drop ┆ … ┆ pu_servic ┆ do_boroug ┆ do_zone   ┆ do_servi │
# │ ---       ┆ ---       ┆ up_dateti ┆ off_datet ┆   ┆ e_zone    ┆ h         ┆ ---       ┆ ce_zone  │
# │ str       ┆ f64       ┆ me        ┆ ime       ┆   ┆ ---       ┆ ---       ┆ str       ┆ ---      │
# │           ┆           ┆ ---       ┆ ---       ┆   ┆ str       ┆ str       ┆           ┆ str      │
# │           ┆           ┆ str       ┆ str       ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 6.590154e ┆ 6590154   ┆ 6590154   ┆ … ┆ 6590154   ┆ 6590154   ┆ 6590154   ┆ 6590154  │
# │           ┆ 6         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ null_coun ┆ 0.0       ┆ 0         ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ 1.756811  ┆ 2024-03-0 ┆ 2024-03-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ 2 23:29:0 ┆ 2 23:45:2 ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 8.306262  ┆ 9.766303  ┆   ┆           ┆           ┆           ┆          │
# │ std       ┆ 0.430632  ┆ null      ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │ min       ┆ 1.0       ┆ 2002-12-3 ┆ 2002-12-3 ┆ … ┆ Airports  ┆ Bronx     ┆ Allerton/ ┆ Airports │
# │           ┆           ┆ 1         ┆ 1         ┆   ┆           ┆           ┆ Pelham    ┆          │
# │           ┆           ┆ 22:17:10  ┆ 22:42:24  ┆   ┆           ┆           ┆ Gardens   ┆          │
# │ 25%       ┆ 2.0       ┆ 2024-02-1 ┆ 2024-02-1 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ 6         ┆ 6         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 23:06:24  ┆ 23:22:02  ┆   ┆           ┆           ┆           ┆          │
# │ 50%       ┆ 2.0       ┆ 2024-03-0 ┆ 2024-03-0 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ 3         ┆ 3         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 14:05:02  ┆ 14:23:32  ┆   ┆           ┆           ┆           ┆          │
# │ 75%       ┆ 2.0       ┆ 2024-03-1 ┆ 2024-03-1 ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆           ┆ 7         ┆ 7         ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆ 12:36:18  ┆ 12:54:35  ┆   ┆           ┆           ┆           ┆          │
# │ max       ┆ 6.0       ┆ 2024-04-0 ┆ 2024-04-0 ┆ … ┆ Yellow    ┆ Unknown   ┆ Yorkville ┆ Yellow   │
# │           ┆           ┆ 1         ┆ 2         ┆   ┆ Zone      ┆           ┆ West      ┆ Zone     │
# │           ┆           ┆ 00:34:55  ┆ 18:08:46  ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
currency_columns = [
    "fare_amount",
    "extra",
    "mta_tax",
    "tip_amount",
    "tolls_amount",
    "improvement_surcharge",
    "total_amount",
    "congestion_surcharge",
    "airport_fee",
]

remove_impossible_data_filter = (
    # Data in expected time range.
    pl.col("tpep_pickup_datetime").ge(pl.date(2024, 2, 1))
    & pl.col("tpep_pickup_datetime").lt(pl.date(2024, 4, 1))
    &
    # Dropoff strictly after the pickup.
    pl.col("tpep_pickup_datetime").lt(pl.col("tpep_dropoff_datetime"))
    &
    # No trips with zero passengers.
    pl.col("passenger_count").gt(0)
    &
    # No negative values in currency columns or `"trip_distance"`.
    pl.all_horizontal(pl.col(["trip_distance"] + currency_columns).ge(0))
    &
    # No missing values.
    pl.all_horizontal(pl.all().is_not_null())
)

# %%
(
    rides_df_raw.select(
        remove_impossible_data_filter.mean().alias("fraction_data_usable")
    )
)
# Out:
# shape: (1, 1)
# ┌──────────────────────┐
# │ fraction_data_usable │
# │ ---                  │
# │ f64                  │
# ╞══════════════════════╡
# │ 0.883446             │
# └──────────────────────┘

# %% [markdown]
# For our cases, it's fine to remove!

# %% [markdown]
# Before removing data, though, let's first prepare to split our data into train and test. We'll do that by splitting the data into 80% and 20%, over time:

# %%
TRAIN_TEST_SPLIT_FRACTION = 0.8
rides_df = rides_df_raw.filter(remove_impossible_data_filter).with_columns(
    pl.col("tpep_pickup_datetime")
    .lt(
        pl.col("tpep_pickup_datetime").min()
        + TRAIN_TEST_SPLIT_FRACTION
        * (
            pl.col("tpep_pickup_datetime").max()
            - pl.col("tpep_pickup_datetime").min()
        )
    )
    .alias("is_train")
)

# %%
rides_df.head()
# Out:
# shape: (5, 26)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ vendor_id ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ do_boroug ┆ do_zone   ┆ do_servic ┆ is_train │
# │ ---       ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ h         ┆ ---       ┆ e_zone    ┆ ---      │
# │ i32       ┆ me        ┆ ime       ┆ ---       ┆   ┆ ---       ┆ str       ┆ ---       ┆ bool     │
# │           ┆ ---       ┆ ---       ┆ i64       ┆   ┆ str       ┆           ┆ str       ┆          │
# │           ┆ datetime[ ┆ datetime[ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Manhattan ┆ Upper     ┆ Yellow    ┆ true     │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆           ┆ East Side ┆ Zone      ┆          │
# │           ┆ 00:04:45  ┆ 00:19:58  ┆           ┆   ┆           ┆ North     ┆           ┆          │
# │ 2         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Manhattan ┆ Washingto ┆ Boro Zone ┆ true     │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆           ┆ n Heights ┆           ┆          │
# │           ┆ 00:56:31  ┆ 01:10:53  ┆           ┆   ┆           ┆ North     ┆           ┆          │
# │ 2         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 2         ┆ … ┆ Manhattan ┆ World     ┆ Yellow    ┆ true     │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆           ┆ Trade     ┆ Zone      ┆          │
# │           ┆ 00:07:50  ┆ 00:43:12  ┆           ┆   ┆           ┆ Center    ┆           ┆          │
# │ 1         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Manhattan ┆ Midtown   ┆ Yellow    ┆ true     │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆           ┆ North     ┆ Zone      ┆          │
# │           ┆ 00:01:49  ┆ 00:10:47  ┆           ┆   ┆           ┆           ┆           ┆          │
# │ 1         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Manhattan ┆ East      ┆ Yellow    ┆ true     │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆           ┆ Village   ┆ Zone      ┆          │
# │           ┆ 00:37:35  ┆ 00:51:15  ┆           ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Time for some ML!

# %% [markdown]
# ## 9.5. Feature Engineering and Selection

# %%
rides_df.head(1)
# Out:
# shape: (1, 26)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ vendor_id ┆ tpep_pick ┆ tpep_drop ┆ passenger ┆ … ┆ do_boroug ┆ do_zone   ┆ do_servic ┆ is_train │
# │ ---       ┆ up_dateti ┆ off_datet ┆ _count    ┆   ┆ h         ┆ ---       ┆ e_zone    ┆ ---      │
# │ i32       ┆ me        ┆ ime       ┆ ---       ┆   ┆ ---       ┆ str       ┆ ---       ┆ bool     │
# │           ┆ ---       ┆ ---       ┆ i64       ┆   ┆ str       ┆           ┆ str       ┆          │
# │           ┆ datetime[ ┆ datetime[ ┆           ┆   ┆           ┆           ┆           ┆          │
# │           ┆ ns]       ┆ ns]       ┆           ┆   ┆           ┆           ┆           ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 2         ┆ 2024-02-0 ┆ 2024-02-0 ┆ 1         ┆ … ┆ Manhattan ┆ Upper     ┆ Yellow    ┆ true     │
# │           ┆ 1         ┆ 1         ┆           ┆   ┆           ┆ East Side ┆ Zone      ┆          │
# │           ┆ 00:04:45  ┆ 00:19:58  ┆           ┆   ┆           ┆ North     ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Earlier in this course, we saw that more rides took place on the weekend; perhaps `"is_weekend"` would have something to do with `"tip_amount"`, so let's add that as a feature. It'll also be curious to include `"is_airport_dropoff"` and `"is_airport_pickup"` as features, which we can extract from the pickup and dropoff location names.
#
# Let's select a basic list of features for an ML experiment:
# - `"is_weekend"`
# - `"is_airport_dropoff"`
# - `"is_airport_pickup"`
# - `"trip_distance"`
# - `"passenger_count"`
# - `"total_amount"`
#
# And of course we'll need to still include `"tip_amount"`:

# %%
FEATURES = [
    "is_weekend",
    "pu_zone_is_airport",
    "do_zone_is_airport",
    "trip_distance",
    "passenger_count",
    "total_amount",
]
TARGET = "tip_amount"
TRAIN_TEST_COLUMN = "is_train"

features_df = rides_df.with_columns(
    [
        pl.col("tpep_pickup_datetime")
        .dt.weekday()
        .is_in({5, 6, 7})
        .alias("is_weekend"),
        pl.col(["pu_zone", "do_zone"])
        .str.contains("Airport")
        .name.suffix("_is_airport"),
    ]
).select(*FEATURES, TARGET, TRAIN_TEST_COLUMN)

# %% [markdown]
# Taking a quick look at the new `features_df`:

# %%
features_df.head()
# Out:
# shape: (5, 8)
# ┌────────────┬────────────┬────────────┬────────────┬───────────┬───────────┬───────────┬──────────┐
# │ is_weekend ┆ pu_zone_is ┆ do_zone_is ┆ trip_dista ┆ passenger ┆ total_amo ┆ tip_amoun ┆ is_train │
# │ ---        ┆ _airport   ┆ _airport   ┆ nce        ┆ _count    ┆ unt       ┆ t         ┆ ---      │
# │ bool       ┆ ---        ┆ ---        ┆ ---        ┆ ---       ┆ ---       ┆ ---       ┆ bool     │
# │            ┆ bool       ┆ bool       ┆ f64        ┆ i64       ┆ f64       ┆ f64       ┆          │
# ╞════════════╪════════════╪════════════╪════════════╪═══════════╪═══════════╪═══════════╪══════════╡
# │ false      ┆ false      ┆ false      ┆ 4.39       ┆ 1         ┆ 26.78     ┆ 1.28      ┆ true     │
# │ false      ┆ false      ┆ false      ┆ 7.71       ┆ 1         ┆ 45.0      ┆ 9.0       ┆ true     │
# │ false      ┆ true       ┆ false      ┆ 28.69      ┆ 2         ┆ 82.69     ┆ 0.0       ┆ true     │
# │ false      ┆ false      ┆ false      ┆ 1.1        ┆ 1         ┆ 17.15     ┆ 2.85      ┆ true     │
# │ false      ┆ false      ┆ false      ┆ 2.6        ┆ 1         ┆ 20.6      ┆ 0.0       ┆ true     │
# └────────────┴────────────┴────────────┴────────────┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# Perfect! Time for some machine learning 🤓

# %% [markdown]
# ## 9.6. Model Building

# %% [markdown]
# We'll try a basic LGBM regression model. To that end, scikit-learn, LGBM, and XGBoost can all accept `polars` series and dataframes with no extra modification:

# %%
model = (
    LGBMRegressor()
)  # Just use the default model params, for the sake of the demo.
X_train = features_df.filter(pl.col("is_train")).select(FEATURES)
y_train = features_df.filter(pl.col("is_train")).select(TARGET).to_series()
X_test = features_df.filter(pl.col("is_train").not_()).select(FEATURES)
y_test = (
    features_df.filter(pl.col("is_train").not_()).select(TARGET).to_series()
)

model.fit(X_train, y_train)
# Out:
# /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.135698 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 524
# [LightGBM] [Info] Number of data points in the train set: 4661711, number of used features: 6
# [LightGBM] [Info] Start training from score 3.533960
# /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages/sklearn/utils/_tags.py:354: FutureWarning: The LGBMRegressor or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#   warnings.warn(
# LGBMRegressor()

# %% [markdown]
# Now let's evaluate!

# %% [markdown]
# ## 9.7. Model Evaluation

# %%
y_predicted = model.predict(X_test)
mae = mean_absolute_error(y_test, y_predicted)
print(
    f"The mean absolute error of our prediction of `tip_amount` is ${mae:.02f}"
)
# Out:
# /home/ubuntu/miniforge3/envs/scikit-learn-fun/lib/python3.10/site-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# The mean absolute error of our prediction of `tip_amount` is $1.13

# %% [markdown]
# ## 9.8. Discussion

# %% [markdown]
# To understand what we could have done to help the model perform a bit better, let's plot the predictions of `"tip_amount"` against the known values of `"tip_amount"`, using `polars`'s `hvplot` again:

# %%
(
    pl.DataFrame(
        {
            "tip_amount_true": y_test,
            "tip_amount_predicted": y_predicted,
            "absolute_error": (y_test - y_predicted).abs(),
        }
    )
    .sample(10000)
    .hvplot.scatter(
        x="tip_amount_true",
        y="tip_amount_predicted",
        c="absolute_error",
        cmap="coolwarm",
        colorbar=True,
        xlim=(-2, 30),
        ylim=(-2, 30),
    )
)
# Out:
# :Scatter   [tip_amount_true]   (tip_amount_predicted,absolute_error)

# %% [markdown]
# There are a few things to take note of:
# - Many rides had a tip of `$0`, that our model predicted as having a nonzero tip. One approach for fixing this would be to introduce a piecewise modeling approach that appreciates the piecewise nature of the `"tip_amount"` distribution. More specifically, we could introduce a two step model--the first model predicts whether the tip is zero or non-zero, and if the first model predicts a nonzero tip, a second model predicts the exact tip amount.
# - Not only is there a spike at `tip_amount = $0`, but also at `$5` and `$10`. Perhaps there's a way to better incorporate into the model output our prior knowledge that tips are very often given in fixed amounts (`$0`, `$5`, `$10`, ...) or fixed percentages (`15%`, `20%`, `25%`, ...) as we saw in the exploration.
# - The prediction eror appears to increase as a function of `"tip_amount"`, though this makes sense--higher values are more difficult to predict precisely. It nonetheless raises the question, though: should we change the objective function from LGBM's [default RMSE (root mean square error)](https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters) to something that doesn't punish as highly for high errors for high values of `"tip_amount_true"`, such as MAPE (mean absolute percentage error)?
#
# And of course, we could add more features or try new models besides LGBM, introduce cross-validation or hyperparameter tuning... but for now that's it!

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this module, we walked through an example data science problem, learning a few new polars tricks such as `hvplot`, `corr`, and `sample`, and seeing how seamlessly `polars` integrates with the rest of the Python data science toolstack.
